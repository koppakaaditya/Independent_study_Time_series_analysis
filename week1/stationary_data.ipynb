# %%
import pandas as pd
import numpy as np
import holoviews as hv
hv.extension('bokeh')
from statsmodels.tsa.seasonal import seasonal_decompose

df = pd.read_csv(r"/content/us_stock_data_2years_with_cleaned (1).csv")

# df.head()

df_AAPL = df[df["Ticker"] == "AAPL"]

df_AAPL.head()

from bokeh.models.formatters import DatetimeTickFormatter



line =  hv.Curve(df_AAPL,"Date","Close").opts(title="AAPL Stock Closing Price",
    xrotation = 90,
    xlabel="Date",
    ylabel="Close Price (USD)",
    color="black",          # line color
    line_width=1,            # thickness of the line
    alpha=0.8,               # transparency (0 to 1)
    tools=['hover'],         # hover, zoom, pan, box_zoom, reset, save
    width=800,               # figure width (pixels)
    height=400,              # figure height (pixels)
)



line


df_AAPL['Date'] = pd.to_datetime(df_AAPL['Date'])
df_AAPL = df_AAPL.sort_values('Date')

# Set 'Date' as the index for time series analysis
df_AAPL.set_index('Date', inplace=True)


from statsmodels.tsa.seasonal import seasonal_decompose

# Perform decomposition (additive model)
result = seasonal_decompose(df_AAPL['Close'], model='additive', period=30)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8c278217-a7bc-4aea-9620-ccde30e47059'>
#   <div id="bb350f1d-62a5-4adf-a562-c2c5cb2ef13a" data-root-id="8c278217-a7bc-4aea-9620-ccde30e47059" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import pandas as pd
import numpy as np
import holoviews as hv
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
hv.extension('bokeh')

# Load data
df = pd.read_csv(r"/content/us_stock_data_2years_with_cleaned (1).csv")
df_AAPL = df[df["Ticker"] == "AAPL"]

# Preprocess
df_AAPL['Date'] = pd.to_datetime(df_AAPL['Date'])
df_AAPL = df_AAPL.sort_values('Date')
df_AAPL.set_index('Date', inplace=True)

# Decompose
result = seasonal_decompose(df_AAPL['Close'], model='additive', period=30)

# Plot all components
result.plot()
plt.suptitle('Additive Decomposition of AAPL Closing Price', fontsize=16)
plt.show()


# Decompose
result1 = seasonal_decompose(df_AAPL['Close'], model='multiplicative', period=30)

# Plot all components
result1.plot()
plt.suptitle('Multiplicative Decomposition of AAPL Closing Price', fontsize=16)
plt.show()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1e3a0d1f-a517-4d6c-a4fc-7cd781aaf12e'>
#   <div id="ff75501f-012f-4a90-82ab-7f51556e2952" data-root-id="1e3a0d1f-a517-4d6c-a4fc-7cd781aaf12e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from statsmodels.tsa.stattools import kpss,adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plt.figure(figsize=(15,6))
plt.plot(df_AAPL['Close'],label = 'Close price')
plt.title("close price")
plt.xlabel('date')
plt.ylabel('Closing price')
plt.legend()
plt.show()

# %%
df_AAPL['log_close'] = np.log(df_AAPL['Close'])
plt.figure(figsize=(15,6))

plt.plot(df_AAPL['log_close'],label = 'Log transformed')
plt.title("Log transformed close price")
plt.xlabel('date')
plt.ylabel('Closing price')
plt.legend()
plt.show()

# %%
df_AAPL['diff_close'] = df_AAPL['Close'].diff()
plt.figure(figsize=(15,6))

plt.plot(df_AAPL['diff_close'],label = 'Log transformed')
plt.title("Log transformed close price")
plt.xlabel('date')
plt.ylabel('Closing price')
plt.legend()
plt.show()

# %%
df_AAPL['diff__log_close'] = (np.log(df_AAPL['Close'])).diff()
plt.figure(figsize=(15,6))

plt.plot(df_AAPL['diff__log_close'],label = 'Log transformed')
plt.title("Log transformed close price")
plt.xlabel('date')
plt.ylabel('Closing price')
plt.legend()
plt.show()

# %%
df_AAPL.dropna(inplace = True)

# %%
def adf_test(series):
  result = adfuller(series)
  print(f'p-value: {result[1]}')
  if result[1] < 0.05:
    print("the series is in stationary so reject the null Hypothesis")
  else:
    print("the series is non stationary so do not reject null hypothesis")

# %%
adf_test(df_AAPL['diff__log_close'])
# Out:
# p-value: 3.18676592167466e-20
# the series is in stationary so reject the null Hypothesis

# %%
adf_test(df_AAPL['Close'])
# Out:
# p-value: 0.6226483647873388
# the series is non stationary so do not reject null hypothesis

# %%
adf_test(df_AAPL['log_close'])
# Out:
# p-value: 0.7092227872437697
# the series is non stationary so do not reject null hypothesis

# %%
adf_test(df_AAPL['diff_close'])
# Out:
# p-value: 1.4918758042877564e-23
# the series is in stationary so reject the null Hypothesis

# %%
def kpss_test(series):
  result = kpss(series)
  print(f'p-value: {result[1]}')
  if result[1] > 0.05:
    print("the series is in stationary so reject the null Hypothesis")
  else:
    print("the series is non stationary so do not reject null hypothesis")

# %%
kpss_test(df_AAPL['Close'])
# Out:
# p-value: 0.01
# the series is non stationary so do not reject null hypothesis
# /tmp/ipython-input-1081668000.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series)

# %%
kpss_test(df_AAPL['log_close'])
# Out:
# p-value: 0.01
# the series is non stationary so do not reject null hypothesis
# /tmp/ipython-input-1081668000.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result = kpss(series)

# %%
kpss_test(df_AAPL['diff_close'])
# Out:
# p-value: 0.1
# the series is in stationary so reject the null Hypothesis
# /tmp/ipython-input-1081668000.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(series)

# %%
kpss_test(df_AAPL['diff__log_close'])
# Out:
# p-value: 0.1
# the series is in stationary so reject the null Hypothesis
# /tmp/ipython-input-1081668000.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   result = kpss(series)

# %%
fig,axis = plt.subplots(4,2,figsize=(10,14))
plot_acf(df_AAPL['Close'],ax = axis[0,0],title='acf_original')
plot_pacf(df_AAPL['Close'],ax = axis[0,1],title='pacf_original')

plot_acf(df_AAPL['log_close'],ax = axis[1,0],title='acf_log')
plot_pacf(df_AAPL['log_close'],ax = axis[1,1],title='pacf_log')


plot_acf(df_AAPL['diff_close'],ax = axis[2,0],title='acf_log')
plot_pacf(df_AAPL['diff_close'],ax = axis[2,1],title='pacf_log')

plot_acf(df_AAPL['diff__log_close'],ax = axis[3,0],title='acf_log')
plot_pacf(df_AAPL['diff__log_close'],ax = axis[3,1],title='pacf_log')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from statsmodels.graphics.tsaplots import plot_acf


# --- 1. Simulate Stock Data and Calculate Returns ---
def prepare_time_series_data() -> pd.DataFrame:
    """
    Simulates stock price data and converts it to log returns for stationarity.

    Returns:
        pd.DataFrame: DataFrame containing 'Close' prices and stationary 'Returns'.
    """
    np.random.seed(42)
    # Simulate a price series with trend and noise
    prices = 100 + np.cumsum(np.random.randn(200) * 0.5) + np.linspace(0, 10, 200)
    data = pd.DataFrame({'Close': prices})

    # The fundamental shift: Use log returns to approximate stationarity
    data['Returns'] = np.log(data['Close'] / data['Close'].shift(1))
    return data.dropna()

data = prepare_time_series_data()

print("--- Data Snapshot ---")
print(data.head())

# --- 2. Autocorrelation Analysis ---
# Visualize ACF for prices (Non-stationary) and returns (Closer to stationary)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plot_acf(data['Close'], lags=20, ax=axes[0], title='ACF: Closing Price (Non-stationary)')
plot_acf(data['Returns'], lags=20, ax=axes[1], title='ACF: Log Returns (Closer to stationary)')
plt.show()


# --- 3. Sequence Transformation using PyTorch Dataset ---

class StockTimeSeriesDataset(Dataset):
    """
    A PyTorch Dataset for creating time series sequences (Lookback Windows)
    from a 1D data array.
    """
    def __init__(self, data_array: np.ndarray, lookback: int):
        """
        Initializes the dataset.

        Args:
            data_array: 1D NumPy array of the time series feature (e.g., returns).
            lookback: The length of the input sequence (Time Steps).
        """
        # Convert NumPy to PyTorch tensor, and add a feature dimension (unsqueeze)
        self.data_tensor = torch.tensor(data_array, dtype=torch.float32).unsqueeze(-1).contiguous()
        self.lookback = lookback
        self.num_samples = len(data_array) - lookback

    def __len__(self) -> int:
        """
        Returns the total number of sequences/samples in the dataset.
        """
        return self.num_samples

    def __getitem__(self, idx: int) -> tuple[torch.Tensor, torch.Tensor]:
        """
        Retrieves one input sequence (X) and its corresponding target (y).

        Args:
            idx: Index of the sample to retrieve.

        Returns:
            tuple[torch.Tensor, torch.Tensor]:
                The input sequence (X) of shape (lookback, 1) and the target
                value (y) of shape (1, 1).
        """
        # X: Sequence from index 'idx' up to 'idx + lookback'
        x = self.data_tensor[idx:idx + self.lookback]
        # y: Target value immediately after the sequence
        y = self.data_tensor[idx + self.lookback]
        return x, y

# Configuration
RETURNS_ARRAY = data['Returns'].values
LOOKBACK = 10  # 10 days of history
BATCH_SIZE = 32

# Create Dataset and DataLoader
dataset = StockTimeSeriesDataset(RETURNS_ARRAY, LOOKBACK)
data_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)

# Get the shape of the first batch
first_batch_x, first_batch_y = next(iter(data_loader))

print("\n--- PyTorch DataLoader Shapes ---")
print(f"Total number of samples: {len(dataset)}")
print(f"Batch Size: {BATCH_SIZE}")
print(f"First Batch X shape (Batch, Timesteps, Features=1): {first_batch_x.shape}")
print(f"First Batch Y shape (Batch, Features=1): {first_batch_y.shape}")
# Out:
# --- Data Snapshot ---
#         Close   Returns
# 1  100.229476 -0.000188
# 2  100.603572  0.003725
# 3  101.415338  0.008037
# 4  101.348512 -0.000659
# 5  101.281695 -0.000659
# --- PyTorch DataLoader Shapes ---
# Total number of samples: 189
# Batch Size: 32
# First Batch X shape (Batch, Timesteps, Features=1): torch.Size([32, 10, 1])
# First Batch Y shape (Batch, Features=1): torch.Size([32, 1])

# %%
import numpy as np

# closing prices
close = np.array([100, 102, 101, 103, 105, 107, 106, 108, 110, 111])

# mean
mean_close = np.mean(close)

# autocovariance for all lags
n = len(close)
autocov_values = []

for lag in range(1, n):  # lags 1 to 9
    cov = np.sum((close[lag:] - mean_close) * (close[:-lag] - mean_close)) / (n - lag)
    autocov_values.append(cov)
    print(f"Lag {lag}: Autocovariance = {cov}")
# Out:
# Lag 1: Autocovariance = 9.367777777777778
# Lag 2: Autocovariance = 6.352499999999999
# Lag 3: Autocovariance = 2.204285714285714
# Lag 4: Autocovariance = -0.8266666666666662
# Lag 5: Autocovariance = -7.090000000000001
# Lag 6: Autocovariance = -11.485000000000001
# Lag 7: Autocovariance = -18.11
# Lag 8: Autocovariance = -21.859999999999996
# Lag 9: Autocovariance = -30.209999999999997
